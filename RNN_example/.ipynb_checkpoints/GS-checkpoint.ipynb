# %%
import tensorflow as tf
import random
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(14)

# %%
df = pd.read_csv("assets/rspb20170679_si_005.csv")

df.columns = ["Year","Pencillin(R)", "Erythromycin(R)","Multidrug(R)","Amoxicillin(C)",
              "Amoxicillin-Clavunate(C)","Amoxicillin-Total(C)","Cephalosporins(C)",
              "Azithromycin(C)","ConcTotal(C)"]
df = df.set_index("Year")
df.head(2)
# Out:
#              Pencillin(R)  Erythromycin(R)  Multidrug(R)  Amoxicillin(C)  \
# Year
# 1999.000000       19.9071          0.00000      0.050406         222.186
# 1999.083333       47.2212          2.51094      9.361640         251.312
#
#              Amoxicillin-Clavunate(C)  Amoxicillin-Total(C)  \
# Year
# 1999.000000                   67.4306              289.6166
# 1999.083333                   71.1567              322.4687
#
#              Cephalosporins(C)  Azithromycin(C)  ConcTotal(C)
# Year
# 1999.000000            37.6809          4.12793       358.506
# 1999.083333            25.5851          2.61499       382.361

# %% [markdown]
# Recall that by using VIF's it was appearent that the pencillins e.g., Amoxicillin and Cephalosporins was really multicolinear. So preferably this two shouldn't be used at once.

# %% [markdown]
# So what feature that will be used for each Anitbiotica resistence forecast is dependent on it's importance that was found with Random Forest regressor.

# %% [markdown]
# For Multidrug reistance Azithromycin and Amoxicillin-Total prescription had the most importance.

# %%
Multidrug_X = df[["Multidrug(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values

# %% [markdown]
# For Erythromycin Azithromycin and Amoxicillin-Total was the most important.

# %%
Erythromycin_X = df[["Erythromycin(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values

# %% [markdown]
# For pencillin Cephalosporins and Azithromycin-Total was the most important.

# %%
Pencillin_x = df[["Pencillin(R)","Cephalosporins(C)",
                 "Azithromycin(C)"]].values

# %% [markdown]
# In this forecasting the data will include number of months which it consider where it then predict the couple of moths. More speciacically, in this experiemnt a period of months is used and with one month horizon i.e., it will predict the resistance one month a head.

# %%
num_periods, f_horizon = 7, 1

# %% [markdown]
# Remark: the four last days in the last training sample will be the same as the four first day in the test sample. One could argue that it's a little bit of cheating.

# %%
def train_data(data, num_periods=7, f_horizon=1, scale=False):    
    n, m = data.shape

    x_data = data[:(len(data) - (len(data) % num_periods))]
    y_data = data[1:(len(data)-(len(data) % num_periods)) + f_horizon]
    
    if scale:
        std_scale = preprocessing.StandardScaler().fit(x_data, y_data)
        x_data = std_scale.transform(x_data)
        y_data = std_scale.transform(y_data)
    
    
    
    x_batches = x_data.reshape(-1, num_periods, m)
    y_batches = y_data.reshape(-1, num_periods, m)
    
    if scale:
        return x_batches, y_batches, std_scale
    else:
        return x_batches, y_batches

# %%
def test_data(data, num_periods, forecast, std_scale=None):
    n,m = data.shape
    
    test_x_setup = data[-(num_periods +  forecast):]
    
    if std_scale:
        test_x_setup = std_scale.transform(test_x_setup)
    
    testX = test_x_setup[:num_periods].reshape(-1, num_periods, m)
    
    if std_scale:
        testY = std_scale.transform(data[-(num_periods):]).reshape(-1, num_periods, m)
    else:
        testY = data[-(num_periods):].reshape(-1, num_periods, m)
    return testX, testY

# %%
from tensorflow.contrib.distributions import Bernoulli

class StochasticRNNLayer:
    """
    StochasticLayer Dense Layer.

    Parameters
    ----------
    BN : bool
        Batchnormalization
    n_in : int
        Input nodes
    n_out: int
        Output nodes
    model_prob: float
        Dropout probability
    model_lam: float
        regualarization term
    is_training: bool
        traing-phase/test-phase        
    
    Returns
    -------
    array
        Outputlayer
    """
    

    def __init__(self, n_in, n_out, model_prob, model_lam, is_training, BN=False, decay=0.99):
        
        
        self.n_in = n_in
        self.n_out = n_out
        
        self.is_training = is_training    
        self.model_prob = model_prob
        self.model_lam = model_lam
        self.model_bern = Bernoulli(probs=self.model_prob, dtype=tf.float32)
        
        self.model_M = tf.Variable(tf.truncated_normal([n_in, n_out], stddev=0.01))
        self.model_m = tf.Variable(tf.zeros([n_out]))
        self.model_W = tf.matmul(
            tf.diag(self.model_bern.sample((n_in, ))), self.model_M
        )
        
        #Parameters for BatchNormalization
        self.BN = BN
        self.scale = tf.Variable(tf.ones([n_out]))
        self.beta = tf.Variable(tf.zeros([n_out]))
        self.epsilon = 1e-2
        self.mean = tf.Variable(tf.zeros([n_out]), trainable=False)
        self.var = tf.Variable(tf.ones([n_out]), trainable=False)
        self.decay = decay

    def __call__(self, X, activation=tf.identity):
        
        basic_cell = tf.contrib.rnn.OutputProjectionWrapper(
            tf.contrib.rnn.BasicLSTMCell(num_units=self.n_in, activation=lambda x: tf.nn.leaky_relu(x, alpha=0.05)),
            output_size=self.n_in
        )
        
            
        rnn_output, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)
        

        #rnn_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(self.n_in), tf.contrib.rnn.BasicLSTMCell(self.n_in)])
        #outputs, states = tf.contrib.rnn.static_rnn(rnn_cell, X, dtype=tf.float32)
            
        #print("rnn_output",rnn_output.shape)
        output = tf.reshape(rnn_output, [-1, self.n_in])
        
        #output = outputs[-1]
        
        
        #output = rnn_output
        #print("data",X.shape)
        #print("output",output.shape)
        #print("mask",self.model_W.shape)
        output = activation(tf.matmul(output, self.model_W) + self.model_m)
        
        if self.BN:
            output = self.batch_norm_wrapper(output)
                
        #if self.model_M.shape[1] == m:
        #    output = tf.squeeze(output)
        return output

    @property
    def regularization(self):
        """regularization"""

        return self.model_lam * (
            self.model_prob * tf.reduce_sum(tf.square(self.model_M)) +
            tf.reduce_sum(tf.square(self.model_m))
        )
    


    
    
    def batch_norm_wrapper(self, inputs):
        """
        Batchnormalization

        Parameters
        ----------
        inputs : array
            Batch input
        is_training : bool
            training phase/test phase
        decay: float
            Decrease training of popoulation mean and variance.    
        Returns
        -------
        array
            Normalized batched
        """
        
        
        
        def BN_train():
            """
            Batchnormalization training
 
            Returns
            -------
            array
                Normalized train batch
            """
            batch_mean, batch_var = tf.nn.moments(inputs,[0])
            train_mean = tf.assign(self.mean, self.mean * self.decay + batch_mean * (1 - self.decay))
            train_var = tf.assign(self.var, self.var * self.decay + batch_var * (1 - self.decay))
            #train_mean = tf.assign(self.mean, self.mean + batch_mean)
            #train_var = tf.assign(self.var, self.var + batch_var)
            
            with tf.control_dependencies([train_mean, train_var]):
                return tf.nn.batch_normalization(inputs,
                    batch_mean, batch_var, self.beta, self.scale, self.epsilon)
            
        def BN_test():
            """
            Batchnormalization test
 
            Returns
            -------
            array
                Normalized test batched
            """
            return tf.nn.batch_normalization(inputs,
                self.mean, self.var, self.beta, self.scale, self.epsilon)
        
        
        return tf.cond(self.is_training, BN_train, BN_test)

# %%
def build_graph(num_periods, features, learning_rate=0.001,dp_prob=1.0, BN=False, decay=0.99,hidden=100,bs=10, model_lam=1e-2):
    #num_periods = x_batches.shape[1]
    inputs = features
    hidden = hidden
    #output = features
    output = 1
    model_prob = dp_prob
    model_lam = model_lam
    learning_rate = learning_rate



    X = tf.placeholder(tf.float32, [None, num_periods, inputs])
    
    #X = tf.reshape(z, [-1, num_periods*inputs])
    #X = tf.split(X, num_periods, 1)
    
    
    y = tf.placeholder(tf.float32, [None, num_periods, output])

    is_training = tf.placeholder(tf.bool)
    
    Layer_1 = StochasticRNNLayer(hidden, hidden, model_prob, model_lam, is_training ,BN=BN, decay=decay)

    z_1 = Layer_1(X,lambda x: tf.nn.leaky_relu(x, alpha=0.05))

    


    stacked_outputs = tf.layers.dense(z_1, output)
    y_pred = tf.reshape(stacked_outputs, [-1, num_periods, output])
    
    sse = tf.reduce_sum(tf.square(y_pred - y)) 

    mse = sse / bs
    
    model_loss = (
        # Negative log-likelihood.
        sse +
        # Regularization.
        Layer_1.regularization 
        
                ) / bs
    
    
    train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(model_loss)

    return (X, y), train_step, mse, y_pred, tf.train.Saver(), is_training

# %%
def train(x_batches,y_batch,iterations=2000, verbose =True, bs=10):
    """
    Train model

    Parameters
    ----------
    iterations : int
        Number of iterations
    verbose : bool
        Verbose
    bs: int
        batch-size
    """
    with tf.Session() as sess:
        tf.set_random_seed(1234)
        sess.run(tf.global_variables_initializer())
        for i in range(iterations):
            #Run it in batches.
            test_idx = np.arange(0 , len(x_batches[0]))
            #np.random.shuffle(test_idx)
            X_batch = x_batches[test_idx[:bs]]
            y_batch = y_batches[test_idx[:bs]]
        
        
            train_step.run(feed_dict={X_input: X_batch, y_input: y_batch, is_training:True})
            if verbose:
                if i % 100 == 0:
                    print(i)
                    mse = sess.run(model_mse, {X_input: X_batch, y_input: y_batch, is_training:True})
                    print("Iteration {}, Mean squared errror: {:.7f}".format(i, mse))
        saved_model = saver.save(sess, 'temp/temp-bn-save')
        sess.close()

# %%
def test(x_batches,X_test,features,samples=1000, bs=10,BN=False):
    """
    Test model

    Parameters
    ----------
    samples : int
        Monte Carlo Samples
    bs : int
        Batchnorm samples
    """
    
    with tf.Session() as sess:
        tf.set_random_seed(1234)
        sess.run(tf.global_variables_initializer())
        saver.restore(sess, 'temp/temp-bn-save')
    

        Y_sample = np.zeros((samples, x_batches.shape[1], features))
        for i in range(samples):       
            if BN:
                test_idx = np.arange(0 , x_batches.shape[0])
                np.random.shuffle(test_idx)
                model_pred.eval({X_input: x_batches[test_idx[:bs]],  is_training: True})
            Y_sample[i] = sess.run(model_pred, {X_input: X_test, is_training: False})
        return Y_sample

# %%
def plot(y_samples, y_test, plt_nr=None):
    if plt_nr:
        print("####Plot {} ####".format(plt_nr))
    if True:
        plt.figure(figsize=(8,6))
    for i in range(samples):
        plt.plot(pd.Series(np.ravel(y_samples[i])), "b-", alpha=1. / 200)
    
    plt.plot(pd.Series(np.ravel(y_test)), "ro", markersize=10, label="Actual")
    plt.errorbar(np.arange(len(y_test.flatten())), np.mean(y_samples, axis=0), yerr=np.std(y_samples,axis=0))
    #plt.errorbar(np.arange(np.ravel(y_samples[i])),pd.Series(np.ravel(np.mean(y_samples,axis=0))), "r-", markersize=10, label="Mean")

# %% [markdown]
# # BDNN Multidrug rescistance Forecasting

# %%
decay= 0.81111
bs = 6
dp_prob = 0.38333
BN=True
hidden= 56
samples = 1000
iterations=  3 * 1000
model_lam = 0.42102
learning_rate = 0.01805

# %%
features = Multidrug_X.shape[1]

# %%
x_batches, y_batches = train_data(Multidrug_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Multidrug_X, num_periods,f_horizon)

# %%
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]

# %%
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam,
                                                                               learning_rate=learning_rate
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)
# Out:
# WARNING:tensorflow:From <ipython-input-331-b2b456e4317c>:58: __init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# 0
# Iteration 0, Mean squared errror: 3437.1367188
# 100
# Iteration 100, Mean squared errror: 422.7171631
# 200
# Iteration 200, Mean squared errror: 291.8016968
# 300
# Iteration 300, Mean squared errror: 106.7265015
# 400
# Iteration 400, Mean squared errror: 131.4631348
# 500
# Iteration 500, Mean squared errror: 119.7884979
# 600
# Iteration 600, Mean squared errror: 108.7573166
# 700
# Iteration 700, Mean squared errror: 82.4373856
# 800
# Iteration 800, Mean squared errror: 137.4183807
# 900
# Iteration 900, Mean squared errror: 110.0190430
# 1000
# Iteration 1000, Mean squared errror: 109.0356598
# 1100
# Iteration 1100, Mean squared errror: 64.1442032
# 1200
# Iteration 1200, Mean squared errror: 55.3260460
# 1300
# Iteration 1300, Mean squared errror: 68.2182465
# 1400
# Iteration 1400, Mean squared errror: 88.8723755
# 1500
# Iteration 1500, Mean squared errror: 56.7841568
# 1600
# Iteration 1600, Mean squared errror: 45.8842621
# 1700
# Iteration 1700, Mean squared errror: 59.3423157
# 1800
# Iteration 1800, Mean squared errror: 44.1193237
# 1900
# Iteration 1900, Mean squared errror: 45.5717545
# 2000
# Iteration 2000, Mean squared errror: 38.2924004
# 2100
# Iteration 2100, Mean squared errror: 55.5522461
# 2200
# Iteration 2200, Mean squared errror: 45.9741631
# 2300
# Iteration 2300, Mean squared errror: 36.1948395
# 2400
# Iteration 2400, Mean squared errror: 35.2636337
# 2500
# Iteration 2500, Mean squared errror: 22.2763348
# 2600
# Iteration 2600, Mean squared errror: 34.5425911
# 2700
# Iteration 2700, Mean squared errror: 41.7515373
# 2800
# Iteration 2800, Mean squared errror: 24.8552895
# 2900
# Iteration 2900, Mean squared errror: 32.4453316

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)

# %%
y_ = Y_sample_DP.mean(axis=0).flatten()
Y_test_ = Y_test.flatten()
np.mean(Y_test_ - y_)**2
# Out:
# 6.873938982164799

# %%
iterations=  3 * 1000
param = dict()
param["decay"] = np.linspace(0.7,0.95,10)
param["dp_prob"] = np.linspace(0.1,0.95,10)
param["hidden"] = np.linspace(10,150,10)
param["bs"] = [6]
param["model_lam"] = np.geomspace(1e-4,0.8,15)
param["lr"] = np.geomspace(0.0001,0.01,10)

# %%
save_param = list()
save_predictions = list()
save_loss = list()
for i in range(2):
    decay = param["decay"][np.random.choice(len(param["decay"]),1)][0]
    dp_prob = param["dp_prob"][np.random.choice(len(param["dp_prob"]),1)][0]
    hidden = int(param["hidden"][np.random.choice(len(param["hidden"]),1)][0])
    bs = 6
    model_lam = param["model_lam"][np.random.choice(len(param["model_lam"]),1)][0]
    lr = param["lr"][np.random.choice(len(param["lr"]),1)][0]
    
    save_param.append([decay,dp_prob,hidden,bs,model_lam,lr])
    
    
    
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam,learning_rate=lr
                                                                              )
    train(x_batches, y_batches, iterations=iterations,verbose = False, bs=bs)
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam,
                                                                                            learning_rate=lr
                                                                                       )
    Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
    Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
    
    save_predictions.append(Y_sample_DP)
    Y_test = np.expand_dims(Y_test[:,:,0],-1)
    y_ = Y_sample_DP.mean(axis=0).flatten()
    Y_test_ = Y_test.flatten()
    loss = np.mean(Y_test_ - y_)**2
    print("#####",i, loss,"####")
    save_loss.append(loss)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ('#####', 0, 3.1021092692289, '####')
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ('#####', 1, 2.6281459382188532, '####')

# %%
ix = np.array(save_loss) > 10.0

# %%
np.array(save_param)[ix]
# Out:
# array([], shape=(0, 6), dtype=float64)

# %%
ix = np.array(save_loss) < 10

# %%
np.array(save_param)[ix]
# Out:
# array([[7.55555556e-01, 8.55555556e-01, 1.34000000e+02, 6.00000000e+00,
#         8.00000000e-01, 1.66810054e-04],
#        [9.50000000e-01, 2.88888889e-01, 1.50000000e+02, 6.00000000e+00,
#         2.21567319e-01, 1.29154967e-03]])

# %%
np.array(save_predictions).shape
# Out:
# (2, 1000, 7, 1)

# %%
f = np.array(save_predictions)[ix]

# %%
np.std(f[0],axis=0)
# Out:
# array([[0.82591067],
#        [0.9367707 ],
#        [0.93566242],
#        [0.94758712],
#        [0.5165326 ],
#        [0.64858613],
#        [1.0984027 ]])

# %%
for i, y_pred in enumerate(f):
    #print(np.std(y_pred,axis=0))
    plot(y_pred, Y_test, plt_nr=i)
# Out:
# ####Plot 1 ####

# %%
ix = np.array(save_loss) > 20.0
for a in np.array(save_param)[ix]:
    print(np.round(a,5))
# Out:
# [ 0.75556  0.95    10.       6.       0.22157  0.05833]
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
ix = np.array(save_loss) < 5
np.array(save_param)[ix]
for a in np.array(save_param)[ix]:
    print(np.round(a,5))
# Out:
# [7.2778e-01 1.9444e-01 1.5000e+02 6.0000e+00 1.0000e-04 6.8040e-02]
# [7.5556e-01 1.0000e-01 1.5000e+02 6.0000e+00 1.1660e-01 5.0000e-02]
# [ 0.95     0.95    72.       6.       0.42102  0.09259]
# [7.8333e-01 8.5556e-01 1.1800e+02 6.0000e+00 8.0000e-01 6.3000e-02]
# [9.2222e-01 3.8333e-01 1.0300e+02 6.0000e+00 2.2157e-01 7.3490e-02]
# [8.9444e-01 6.6667e-01 1.0000e+01 6.0000e+00 6.9000e-04 5.8330e-02]
# [8.1111e-01 7.6111e-01 4.1000e+01 6.0000e+00 3.6000e-04 1.0000e-01]
# [ 0.72778  0.76111 41.       6.       0.06137  0.063  ]
# [8.6667e-01 8.5556e-01 8.7000e+01 6.0000e+00 2.4800e-03 7.9370e-02]
# [ 0.72778  0.47778 56.       6.       0.22157  0.09259]
# [8.9444e-01 4.7778e-01 4.1000e+01 6.0000e+00 6.9000e-04 5.8330e-02]
# [7.2778e-01 1.0000e-01 5.6000e+01 6.0000e+00 8.9400e-03 8.5720e-02]
# [7.2778e-01 4.7778e-01 1.1800e+02 6.0000e+00 1.9000e-04 6.3000e-02]
# [7.5556e-01 7.6111e-01 2.5000e+01 6.0000e+00 1.0000e-04 7.3490e-02]
# [7.8333e-01 8.5556e-01 1.5000e+02 6.0000e+00 3.2290e-02 7.3490e-02]
# [8.1111e-01 6.6667e-01 2.5000e+01 6.0000e+00 8.9400e-03 9.2590e-02]
# [8.6667e-01 2.8889e-01 8.7000e+01 6.0000e+00 8.0000e-01 7.9370e-02]
# [8.9444e-01 1.0000e-01 1.0300e+02 6.0000e+00 6.1370e-02 1.0000e-01]
# [7.8333e-01 7.6111e-01 1.1800e+02 6.0000e+00 4.7100e-03 5.8330e-02]
# [8.9444e-01 6.6667e-01 5.6000e+01 6.0000e+00 3.2290e-02 6.3000e-02]
# [7.8333e-01 6.6667e-01 7.2000e+01 6.0000e+00 1.1660e-01 5.8330e-02]
# [8.3889e-01 3.8333e-01 1.3400e+02 6.0000e+00 8.9400e-03 6.3000e-02]
# [7.5556e-01 9.5000e-01 5.6000e+01 6.0000e+00 2.4800e-03 1.0000e-01]
# [7.8333e-01 6.6667e-01 1.5000e+02 6.0000e+00 6.9000e-04 1.0000e-01]
# [9.500e-01 1.000e-01 1.030e+02 6.000e+00 1.166e-01 6.300e-02]
# [7.5556e-01 6.6667e-01 1.1800e+02 6.0000e+00 2.4800e-03 5.0000e-02]
# [7.8333e-01 5.7222e-01 1.1800e+02 6.0000e+00 1.0000e-04 8.5720e-02]
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.

# %%
f = np.array(save_predictions)[ix]
for i, y_pred in enumerate(f):
    plot(y_pred, Y_test, plt_nr=i)
# Out:
# ####Plot 1 ####
# ####Plot 2 ####
# ####Plot 3 ####
# ####Plot 4 ####
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/lines.pyc in draw(self, renderer)
#     779
#     780                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 781                 renderer.draw_path(gc, tpath, affine.frozen())
#     782                 gc.restore()
#     783
#
# /home/ekvall/anaconda3/envs/kth-cluster2.7/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw_path(self, gc, path, transform, rgbFace)
#     173         else:
#     174             try:
# --> 175                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     176             except OverflowError:
#     177                 raise OverflowError("Exceeded cell block limit (set "
#
# ValueError: object too deep for desired array

# %% [markdown]
# # BDNN Erythromycin rescistance Forecasting

# %%
decay= 0.81111
bs = 6
dp_prob = 0.38333
BN=True
hidden= 56
samples = 1000
iterations=  3 * 1000
model_lam = 0.42102
learning_rate = 0.01805

# %%
num_periods, f_horizon = 7, 1
features = Erythromycin_X.shape[1]

# %%
features = Multidrug_X.shape[1]
x_batches, y_batches = train_data(Erythromycin_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Erythromycin_X, num_periods,f_horizon)
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)

# %%
param = dict()
param["decay"] = np.linspace(0.2,0.9,10)
param["dp_prob"] = np.linspace(0.3,0.9,10)
param["hidden"] = np.linspace(10,80,15)
param["bs"] = [6]
param["model_lam"] = np.geomspace(1e-4,0.1,15)
param["lr"] = np.geomspace(0.0002,0.01,15)

# %%
save_param = list()
save_predictions = list()
save_loss = list()
for i in range(100):
    decay = param["decay"][np.random.choice(len(param["decay"]),1)][0]
    dp_prob = param["dp_prob"][np.random.choice(len(param["dp_prob"]),1)][0]
    hidden = int(param["hidden"][np.random.choice(len(param["hidden"]),1)][0])
    bs = 6
    model_lam = param["model_lam"][np.random.choice(len(param["model_lam"]),1)][0]
    lr = param["lr"][np.random.choice(len(param["lr"]),1)][0]
    
    save_param.append([decay,dp_prob,hidden,bs,model_lam,lr])
    
    
    
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam,learning_rate=lr
                                                                              )
    train(x_batches, y_batches, iterations=iterations,verbose = False, bs=bs)
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam,
                                                                                            learning_rate=lr
                                                                                       )
    Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
    Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
    
    save_predictions.append(Y_sample_DP)
    Y_test = np.expand_dims(Y_test[:,:,0],-1)
    
    y_mean_ = Y_sample_DP.mean(axis=0).flatten()
    
    y_std_ = Y_sample_DP.std(axis=0).flatten()
    
    y_p = y_mean_ + y_std_
    
    y_m = y_mean_ - y_std_
    
    
    
    
    
    Y_test_ = Y_test.flatten()
    
    
    loss_1 = np.mean((Y_test_ - y_mean_)**2)
    
    bo1 = Y_test_ < y_m
    
    if sum(bo1) > 0:
        loss_2 = np.mean((Y_test_[bo1] - y_m[bo1])**2)
    else:
        loss_2= 0
        
    
    bo2 = y_p < Y_test_ 
    
    if sum(bo2) > 0:
        loss_3 = np.mean((Y_test_[bo2] - y_p[bo2])**2)
    else:
        loss_3= 0
    

    
    loss = loss_1 + loss_2 + loss_3

    print("#####",i, loss,"####")
    save_loss.append(loss)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ('#####',
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ('#####', 99, 363.86807984015536, '####')

# %%
def truncate(f, n=4):
    '''Truncates/pads a float f to n decimal places without rounding'''
    s = '%.12f' % f
    i, p, d = s.partition('.')
    return '.'.join([i, (d+'0'*n)[:n]])

# %%
t = truncate
ix = np.array(save_loss) > 800.0
for k, i in enumerate(np.array(save_param)[ix]):

    print(t(i[0]),t(i[1]),t(i[2]),t(i[3]),t(i[4]),t(i[5]))
# Out:
# ('0.9000', '0.3000', '55.0000', '6.0000', '0.0610', '0.0008')
# ('0.2000', '0.7000', '15.0000', '6.0000', '0.0007', '0.0032')
# ('0.6666', '0.7000', '35.0000', '6.0000', '0.0007', '0.0043')
# ('0.3555', '0.3666', '10.0000', '6.0000', '0.0610', '0.0100')
# ('0.4333', '0.4333', '15.0000', '6.0000', '0.0372', '0.0043')
# ('0.5888', '0.5000', '40.0000', '6.0000', '0.0227', '0.0043')
# ('0.2777', '0.3000', '60.0000', '6.0000', '0.0011', '0.0008')
# ('0.4333', '0.6333', '50.0000', '6.0000', '0.0001', '0.0043')
# ('0.3555', '0.3666', '15.0000', '6.0000', '0.0372', '0.0032')

# %%
t = truncate
ix = np.array(save_loss) < 300.0
for k, i in enumerate(np.array(save_param)[ix]):

    print(t(i[0]),t(i[1]),t(i[2]),t(i[3]),t(i[4]),t(i[5]))
# Out:
# ('0.5888', '0.5666', '45.0000', '6.0000', '0.0007', '0.0003')
# ('0.3555', '0.5000', '25.0000', '6.0000', '0.0011', '0.0002')
# ('0.7444', '0.5666', '10.0000', '6.0000', '0.0002', '0.0003')
# ('0.2000', '0.3000', '15.0000', '6.0000', '0.0051', '0.0010')
# ('0.6666', '0.7666', '10.0000', '6.0000', '0.0002', '0.0014')
# ('0.2000', '0.6333', '40.0000', '6.0000', '0.0019', '0.0004')
# ('0.6666', '0.7666', '20.0000', '6.0000', '0.0610', '0.0002')
# ('0.3555', '0.8333', '25.0000', '6.0000', '0.0610', '0.0008')

# %%
f = np.array(save_predictions)[ix]
#f = np.array(save_predictions)
for i, y_pred in enumerate(f):
    plot(y_pred, Y_test)

# %% [markdown]
# # BDNN Pencillin rescistance Forecasting

# %%
decay=0.9
bs = 5
dp_prob = 0.95
BN=True
hidden= 500
samples = 3000
iterations=  5 * 1000
model_lam = 1e-6

# %%
num_periods, f_horizon = 7, 1
features = Pencillin_x.shape[1]

# %%
x_batches, y_batches = train_data(Pencillin_x, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Pencillin_x, num_periods,f_horizon)

# %%
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)
