# %%
import tensorflow as tf
import random
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(14)
# Out:
# /home/ekvall/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = pd.read_csv("assets/rspb20170679_si_005.csv")

df.columns = ["Year","Pencillin(R)", "Erythromycin(R)","Multidrug(R)","Amoxicillin(C)",
              "Amoxicillin-Clavunate(C)","Amoxicillin-Total(C)","Cephalosporins(C)",
              "Azithromycin(C)","ConcTotal(C)"]
df = df.set_index("Year")
df.head(2)
# Out:
#              Pencillin(R)  Erythromycin(R)  Multidrug(R)  Amoxicillin(C)  \
# Year
# 1999.000000       19.9071          0.00000      0.050406         222.186
# 1999.083333       47.2212          2.51094      9.361640         251.312
#
#              Amoxicillin-Clavunate(C)  Amoxicillin-Total(C)  \
# Year
# 1999.000000                   67.4306              289.6166
# 1999.083333                   71.1567              322.4687
#
#              Cephalosporins(C)  Azithromycin(C)  ConcTotal(C)
# Year
# 1999.000000            37.6809          4.12793       358.506
# 1999.083333            25.5851          2.61499       382.361

# %%
df.shape
# Out:
# (60, 9)

# %%
Multidrug_X = df[["Multidrug(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values
Erythromycin_X = df[["Erythromycin(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values
Pencillin_x = df[["Pencillin(R)","Cephalosporins(C)",
                 "Azithromycin(C)"]].values

# %%
#Pencillin_x = df[["Pencillin(R)","Cephalosporins(C)","Azithromycin(C)"]].values

# %%
#Multidrug_X = df[["Multidrug(R)","Cephalosporins(C)"]].values

# %%
def train_data(data, num_periods=7, f_horizon=1, scale=False):    
    n, m = data.shape

    x_data = data[:(len(data) - (len(data) % num_periods))]
    y_data = data[1:(len(data)-(len(data) % num_periods)) + f_horizon]
    
    if scale:
        std_scale = preprocessing.StandardScaler().fit(x_data, y_data)
        x_data = std_scale.transform(x_data)
        y_data = std_scale.transform(y_data)
    
    
    
    x_batches = x_data.reshape(-1, num_periods, m)
    y_batches = y_data.reshape(-1, num_periods, m)
    
    if scale:
        return x_batches, y_batches, std_scale
    else:
        return x_batches, y_batches

# %%
def test_data(data, num_periods, forecast, std_scale=None):
    n,m = data.shape
    
    test_x_setup = data[-(num_periods +  forecast):]
    
    if std_scale:
        test_x_setup = std_scale.transform(test_x_setup)
    
    testX = test_x_setup[:num_periods].reshape(-1, num_periods, m)
    
    if std_scale:
        testY = std_scale.transform(data[-(num_periods):]).reshape(-1, num_periods, m)
    else:
        testY = data[-(num_periods):].reshape(-1, num_periods, m)
    return testX, testY

# %%
from tensorflow.contrib.distributions import Bernoulli

class StochasticRNNLayer:
    """
    StochasticLayer Dense Layer.

    Parameters
    ----------
    BN : bool
        Batchnormalization
    n_in : int
        Input nodes
    n_out: int
        Output nodes
    model_prob: float
        Dropout probability
    model_lam: float
        regualarization term
    is_training: bool
        traing-phase/test-phase        
    
    Returns
    -------
    array
        Outputlayer
    """
    

    def __init__(self, n_in, n_out, model_prob, is_training, BN=False, decay=0.99):
        
        
        self.n_in = n_in
        self.n_out = n_out
        
        self.is_training = is_training    
        self.model_prob = model_prob
       
        self.model_bern = Bernoulli(probs=self.model_prob, dtype=tf.float32)
       
        #Parameters for BatchNormalization
        self.BN = BN
        self.scale = tf.Variable(tf.ones([n_out]))
        self.beta = tf.Variable(tf.zeros([n_out]))
        self.epsilon = 1e-2
        self.mean = tf.Variable(tf.zeros([n_out]), trainable=False)
        self.var = tf.Variable(tf.ones([n_out]), trainable=False)
        self.decay = decay

    def __call__(self, X, activation=tf.identity):
        
        basic_cell = tf.contrib.rnn.OutputProjectionWrapper(
            tf.contrib.rnn.BasicRNNCell(num_units=self.n_in, activation=tf.nn.relu),
            output_size=self.n_in
        )
        

        
        basic_cell = tf.contrib.rnn.DropoutWrapper(basic_cell, input_keep_prob=self.model_prob[0], output_keep_prob=self.model_prob[1], state_keep_prob=self.model_prob[2])
        
            
        rnn_output, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)
        
        
        
        
        

        #rnn_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(self.n_in), tf.contrib.rnn.BasicLSTMCell(self.n_in)])
        #outputs, states = tf.contrib.rnn.static_rnn(rnn_cell, X, dtype=tf.float32)
            
        #print("rnn_output",rnn_output.shape)
        output = tf.reshape(rnn_output, [-1, self.n_in])
        
        #output = outputs[-1]
        
        
        #output = rnn_output
        #print("data",X.shape)
        #print("output",output.shape)
        #print("mask",self.model_W.shape)
        #output = activation(tf.matmul(output, self.model_W) + self.model_m)
        
        if self.BN:
            output = self.batch_norm_wrapper(output)
                
        #if self.model_M.shape[1] == m:
        #    output = tf.squeeze(output)
        return output

   
    
    def batch_norm_wrapper(self, inputs):
        """
        Batchnormalization

        Parameters
        ----------
        inputs : array
            Batch input
        is_training : bool
            training phase/test phase
        decay: float
            Decrease training of popoulation mean and variance.    
        Returns
        -------
        array
            Normalized batched
        """
        
        
        
        def BN_train():
            """
            Batchnormalization training
 
            Returns
            -------
            array
                Normalized train batch
            """
            batch_mean, batch_var = tf.nn.moments(inputs,[0])
            train_mean = tf.assign(self.mean, self.mean * self.decay + batch_mean * (1 - self.decay))
            train_var = tf.assign(self.var, self.var * self.decay + batch_var * (1 - self.decay))
            #train_mean = tf.assign(self.mean, self.mean + batch_mean)
            #train_var = tf.assign(self.var, self.var + batch_var)
            
            with tf.control_dependencies([train_mean, train_var]):
                return tf.nn.batch_normalization(inputs,
                    batch_mean, batch_var, self.beta, self.scale, self.epsilon)
            
        def BN_test():
            """
            Batchnormalization test
 
            Returns
            -------
            array
                Normalized test batched
            """
            return tf.nn.batch_normalization(inputs,
                self.mean, self.var, self.beta, self.scale, self.epsilon)
        
        
        return tf.cond(self.is_training, BN_train, BN_test)

# %%
def build_graph(num_periods, features, learning_rate=0.01, dp_prob=np.array([1.0,1.0,1.0]), BN=False, decay=0.99,hidden=100,bs=10):
    #num_periods = x_batches.shape[1]
    inputs = features
    hidden = hidden
    #output = features
    output = 1
    model_prob = dp_prob
    learning_rate = learning_rate



    X = tf.placeholder(tf.float32, [None, num_periods, inputs])
    
    #X = tf.reshape(z, [-1, num_periods*inputs])
    #X = tf.split(X, num_periods, 1)
    
    
    y = tf.placeholder(tf.float32, [None, num_periods, output])

    is_training = tf.placeholder(tf.bool)
    
    Layer_1 = StochasticRNNLayer(hidden, hidden, model_prob, is_training ,BN=BN, decay=decay)

    z_1 = Layer_1(X, tf.nn.relu)



    


    stacked_outputs = tf.layers.dense(z_1, output)
    y_pred = tf.reshape(stacked_outputs, [-1, num_periods, output])
    
    sse = tf.reduce_sum(tf.square(y_pred - y)) 

    mse = sse / bs
    
    model_loss = (
        # Negative log-likelihood.
        sse 
                ) / bs
    
    
    train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(model_loss)

    return (X, y), train_step, mse, y_pred, tf.train.Saver(), is_training

# %%
def train(x_batches,y_batch,iterations=2000, verbose =True, bs=10):
    """
    Train model

    Parameters
    ----------
    iterations : int
        Number of iterations
    verbose : bool
        Verbose
    bs: int
        batch-size
    """
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(iterations):
            #Run it in batches.
            test_idx = np.arange(0 , len(x_batches[1]))
            #np.random.shuffle(test_idx)
            X_batch = x_batches[test_idx[:bs]]
            y_batch = y_batches[test_idx[:bs]]
        
        
            train_step.run(feed_dict={X_input: X_batch, y_input: y_batch, is_training:True})
            if verbose:
                if i % 100 == 0:
                    print(i)
                    mse = sess.run(model_mse, {X_input: X_batch, y_input: y_batch, is_training:True})
                    print("Iteration {}, Mean squared errror: {:.7f}".format(i, mse))
        saved_model = saver.save(sess, 'temp/temp-bn-save')
        sess.close()

# %%
def test(x_batches,X_test,features,samples=1000, bs=10,BN=False):
    """
    Test model

    Parameters
    ----------
    samples : int
        Monte Carlo Samples
    bs : int
        Batchnorm samples
    """
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        saver.restore(sess, 'temp/temp-bn-save')
    

        Y_sample = np.zeros((samples, x_batches.shape[1], features))
        for i in range(samples):       
            if BN:
                test_idx = np.arange(0 , x_batches.shape[0])
                np.random.shuffle(test_idx)
                model_pred.eval({X_input: x_batches[test_idx[:bs]],  is_training: True})
            Y_sample[i] = sess.run(model_pred, {X_input: X_test, is_training: False})
        return Y_sample

# %%
def plot(y_samples, y_test):
    if True:
        plt.figure(figsize=(8,6))
    for i in range(samples):
        plt.plot(pd.Series(np.ravel(y_samples[i])), "b-", alpha=1. / 200)
    plt.plot(pd.Series(np.ravel(y_test)), "ro", markersize=10, label="Actual")

# %% [markdown]
# # BDNN Multidrug rescistance Forecasting

# %%
param = [7.27777778e-01, 7.17777778e-01, 6.08888889e-01, 7.17777778e-01,
        4.10000000e+01, 7.00000000e+00, 1.29154967e-03]

# %%
num_periods, f_horizon = 7, 1
decay=param[0]
bs = int(param[5])
dp_prob = np.array([param[1],param[2],param[3]])
BN=True
hidden= int(param[4])
samples = 3000
iterations=  7 * 1000
lr = param[6]

# %%
len(param)
# Out:
# 7

# %%
features = Multidrug_X.shape[1]
x_batches, y_batches = train_data(Multidrug_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Multidrug_X, num_periods,f_horizon)
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)
# Out:
# 0
# Iteration 0, Mean squared errror: 3174.0529785
# 100
# Iteration 100, Mean squared errror: 2795.9526367
# 200
# Iteration 200, Mean squared errror: 1923.1319580
# 300
# Iteration 300, Mean squared errror: 996.4361572
# 400
# Iteration 400, Mean squared errror: 566.4580078
# 500
# Iteration 500, Mean squared errror: 496.4195557
# 600
# Iteration 600, Mean squared errror: 587.7409668
# 700
# Iteration 700, Mean squared errror: 461.2872925
# 800
# Iteration 800, Mean squared errror: 496.7526245
# 900
# Iteration 900, Mean squared errror: 680.1052856
# 1000
# Iteration 1000, Mean squared errror: 521.8995361
# 1100
# Iteration 1100, Mean squared errror: 524.2578125
# 1200
# Iteration 1200, Mean squared errror: 638.2644043
# 1300
# Iteration 1300, Mean squared errror: 548.0476074
# 1400
# Iteration 1400, Mean squared errror: 458.2918091
# 1500
# Iteration 1500, Mean squared errror: 470.3657837
# 1600
# Iteration 1600, Mean squared errror: 495.2008057
# 1700
# Iteration 1700, Mean squared errror: 464.6829529
# 1800
# Iteration 1800, Mean squared errror: 372.2514343
# 1900
# Iteration 1900, Mean squared errror: 481.2693787
# 2000
# Iteration 2000, Mean squared errror: 471.1415405
# 2100
# Iteration 2100, Mean squared errror: 387.3616943
# 2200
# Iteration 2200, Mean squared errror: 472.1110229
# 2300
# Iteration 2300, Mean squared errror: 407.3842468
# 2400
# Iteration 2400, Mean squared errror: 447.9402771
# 2500
# Iteration 2500, Mean squared errror: 338.5108643
# 2600
# Iteration 2600, Mean squared errror: 375.8477478
# 2700
# Iteration 2700, Mean squared errror: 564.7215576
# 2800
# Iteration 2800, Mean squared errror: 492.9894104
# 2900
# Iteration 2900, Mean squared errror: 515.4879150
# 3000
# Iteration 3000, Mean squared errror: 377.6986694
# 3100
# Iteration 3100, Mean squared errror: 444.8837280
# 3200
# Iteration 3200, Mean squared errror: 473.7971802
# 3300
# Iteration 3300, Mean squared errror: 430.3250427
# 3400
# Iteration 3400, Mean squared errror: 404.8419495
# 3500
# Iteration 3500, Mean squared errror: 422.0105896
# 3600
# Iteration 3600, Mean squared errror: 319.8151245
# 3700
# Iteration 3700, Mean squared errror: 464.8492432
# 3800
# Iteration 3800, Mean squared errror: 284.0965881
# 3900
# Iteration 3900, Mean squared errror: 448.6370544
# 4000
# Iteration 4000, Mean squared errror: 339.2413940
# 4100
# Iteration 4100, Mean squared errror: 353.4605408
# 4200
# Iteration 4200, Mean squared errror: 435.0819092
# 4300
# Iteration 4300, Mean squared errror: 284.3356934
# 4400
# Iteration 4400, Mean squared errror: 488.1727905
# 4500
# Iteration 4500, Mean squared errror: 494.4620056
# 4600
# Iteration 4600, Mean squared errror: 264.0671387
# 4700
# Iteration 4700, Mean squared errror: 422.4744873
# 4800
# Iteration 4800, Mean squared errror: 390.8221436
# 4900
# Iteration 4900, Mean squared errror: 477.0687866
# 5000
# Iteration 5000, Mean squared errror: 403.6018677
# 5100
# Iteration 5100, Mean squared errror: 462.1567383
# 5200
# Iteration 5200, Mean squared errror: 465.3778076
# 5300
# Iteration 5300, Mean squared errror: 286.9284363
# 5400
# Iteration 5400, Mean squared errror: 310.1934509
# 5500
# Iteration 5500, Mean squared errror: 319.3993835
# 5600
# Iteration 5600, Mean squared errror: 392.7034912
# 5700
# Iteration 5700, Mean squared errror: 258.8027039
# 5800
# Iteration 5800, Mean squared errror: 305.6924438
# 5900
# Iteration 5900, Mean squared errror: 321.2243042
# 6000
# Iteration 6000, Mean squared errror: 536.6317749

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                                       
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)

# %%
iterations=  7 * 1000
param = dict()
param["decay"] = np.linspace(0.7,0.95,10)

param["dp1"] = np.linspace(0.5,0.99,10)
param["dp2"] = np.linspace(0.5,0.99,10)
param["dp3"] = np.linspace(0.5,0.99,10)

param["hidden"] = np.linspace(10,150,10)
param["bs"] = np.linspace(3,7,5)
param["lr"] = np.geomspace(0.0001,0.01,10)

# %%
param["bs"]
# Out:
# array([3., 4., 5., 6., 7.])

# %%
save_param = list()
save_predictions = list()
save_loss = list()
for i in range(100):
    decay = param["decay"][np.random.choice(len(param["decay"]),1)][0]
    
    dp1 = param["dp1"][np.random.choice(len(param["dp1"]),1)][0]
    dp2 = param["dp2"][np.random.choice(len(param["dp2"]),1)][0]
    dp3 = param["dp3"][np.random.choice(len(param["dp3"]),1)][0]
    dp_prob = np.array([dp1,dp2,dp3])
    
    
    hidden = int(param["hidden"][np.random.choice(len(param["hidden"]),1)][0])
    bs = int(param["bs"][np.random.choice(len(param["bs"]),1)][0])

    lr = param["lr"][np.random.choice(len(param["lr"]),1)][0]
    
    save_param.append([decay,dp1,dp2,dp3,hidden,bs,lr])
    
    
    
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                              )
    train(x_batches, y_batches, iterations=iterations,verbose = False, bs=bs)
    tf.reset_default_graph()
    (X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       
                                                                                            learning_rate=lr
                                                                                       )
    Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
    Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
    
    save_predictions.append(Y_sample_DP)
    Y_test = np.expand_dims(Y_test[:,:,0],-1)
    y_ = Y_sample_DP.mean(axis=0).flatten()
    Y_test_ = Y_test.flatten()
    loss = np.mean(Y_test_ - y_)**2
    print("#####",i, loss,"####")
    save_loss.append(loss)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 0 1.482659224934962 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 1 23.940304390973857 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 2 18.73992259161198 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 3 0.9633826904702029 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 4 0.46792061201862517 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 5 19.795648352662575 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 6 12.144407498968857 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 7 0.12229685803672276 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 8 21.87437183967061 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 9 0.08708365785378078 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 10 12.129994818282903 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 11 23.532905505796982 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 12 11.508389536454127 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 13 4.373291834463404 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 14 1.1948085997448288 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 15 1.2966000472073933 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 16 4.040416557631167 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 17 2.9946787469701994 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 18 8.395128737096837 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 19 19.519029706685213 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 20 3.04214487680017 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 21 5.432333504687773 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 22 36.68182095682846 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 23 47.109821685291564 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 24 5.924087567430444 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 25 1.1317501281081177 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 26 31.880232983309465 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 27 22.02320158909686 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 28 21.92168128452691 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 29 3.7347217417825327 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 30 3.597981239404119 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 31 1.8750603722665637 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 32 0.48257659260984914 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 33 2.4381830666445343 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 34 28.93614010485496 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 35 37.60605995226741 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 36 3.2261351003958327 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 37 1.8044083592871871 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 38 20.224147430902395 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 39 0.02698889235491505 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 40 0.7741615825423226 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 41 15.795527599494333 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 42 21.39687083620827 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 43 25.600111637652624 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 44 15.869047331096615 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 45 16.961477920094318 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 46 1.5245006907268286 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 47 1.7313737129421403 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 48 5.118933094324228 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 49 4.022164148584242 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 50 27.030890666178397 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 51 0.945680861248871 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 52 26.771109226639904 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 53 1.2200984496460314 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 54 22.278788006872237 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 55 0.762827673765016 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 56 5.293778843671493 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 57 0.25334497332019995 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 58 1.2587212125125693 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 59 0.1710873954128097 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 60 18.677862098922205 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 61 0.37840673101690164 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 62 1.47374717068372 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 63 20.675178158077273 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 64 1.4527285745668712 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 65 1.0293949237511575 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 66 33.73703621078248 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 67 0.024264035802214527 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 68 18.60403635768984 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 69 31.184113737632757 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 70 0.9625257192074537 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 71 15.472558000085609 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 72 18.558424164276765 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 73 20.349960091546585 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 74 10.824629377691064 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 75 16.421722683374593 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 76 0.06486481716908322 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 77 2.7471032483870563 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 78 1.6959791090268372 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 79 2.613007951509021 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 80 6.947815156270505 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 81 0.00794987349012348 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 82 24.695707147802903 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 83 1.5939297731823727 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 84 14.635988175670239 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 85 0.3788846530304872 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 86 0.03197507404956886 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 87 0.08554760955946003 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 88 22.016662335173546 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 89 14.7686164706617 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 90 15.194228101497188 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 91 3.8890022463508633 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 92 1.1597877058598746e-05 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 93 1.440718161747268 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 94 0.032204188478259496 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 95 1.1052138605314434 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 96 23.114518779963575 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 97 131.0704275573605 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 98 0.2670112106981795 ####
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save
# ##### 99 2.6303492999918174 ####

# %%
ix = np.array(save_loss) > 30.0

# %%
np.array(save_param)[ix]
# Out:
# array([[7.27777778e-01, 8.26666667e-01, 6.08888889e-01, 6.63333333e-01,
#         5.60000000e+01, 3.00000000e+00, 1.66810054e-04],
#        [7.27777778e-01, 9.90000000e-01, 9.35555556e-01, 5.00000000e-01,
#         4.10000000e+01, 3.00000000e+00, 3.59381366e-03],
#        [8.38888889e-01, 8.81111111e-01, 7.17777778e-01, 8.26666667e-01,
#         1.03000000e+02, 4.00000000e+00, 1.00000000e-04],
#        [9.50000000e-01, 7.72222222e-01, 6.63333333e-01, 7.72222222e-01,
#         1.03000000e+02, 3.00000000e+00, 1.00000000e-04],
#        [9.22222222e-01, 6.63333333e-01, 6.63333333e-01, 9.90000000e-01,
#         7.20000000e+01, 3.00000000e+00, 2.78255940e-04],
#        [8.94444444e-01, 9.90000000e-01, 5.54444444e-01, 5.00000000e-01,
#         8.70000000e+01, 4.00000000e+00, 5.99484250e-03],
#        [8.94444444e-01, 7.72222222e-01, 9.35555556e-01, 6.08888889e-01,
#         1.00000000e+01, 3.00000000e+00, 1.00000000e-04]])

# %%
ix = np.array(save_loss) < 0.1

# %%
np.array(save_param)[ix]
# Out:
# array([[9.50000000e-01, 5.54444444e-01, 5.54444444e-01, 6.08888889e-01,
#         2.50000000e+01, 6.00000000e+00, 7.74263683e-04],
#        [7.83333333e-01, 6.08888889e-01, 7.72222222e-01, 5.54444444e-01,
#         1.50000000e+02, 7.00000000e+00, 1.00000000e-02],
#        [8.11111111e-01, 8.81111111e-01, 8.81111111e-01, 7.17777778e-01,
#         1.03000000e+02, 7.00000000e+00, 2.15443469e-03],
#        [7.83333333e-01, 6.08888889e-01, 9.35555556e-01, 8.26666667e-01,
#         1.34000000e+02, 7.00000000e+00, 3.59381366e-03],
#        [8.38888889e-01, 6.63333333e-01, 7.17777778e-01, 7.72222222e-01,
#         8.70000000e+01, 6.00000000e+00, 2.15443469e-03],
#        [7.83333333e-01, 9.35555556e-01, 7.17777778e-01, 7.17777778e-01,
#         1.18000000e+02, 5.00000000e+00, 1.29154967e-03],
#        [7.27777778e-01, 7.17777778e-01, 6.08888889e-01, 7.17777778e-01,
#         4.10000000e+01, 7.00000000e+00, 1.29154967e-03],
#        [7.27777778e-01, 7.17777778e-01, 7.72222222e-01, 6.08888889e-01,
#         2.50000000e+01, 6.00000000e+00, 5.99484250e-03],
#        [7.27777778e-01, 8.26666667e-01, 5.00000000e-01, 9.35555556e-01,
#         1.03000000e+02, 7.00000000e+00, 1.29154967e-03]])

# %%
np.array(save_param)
# Out:
#         1.00000000e+01, 5.00000000e+00, 1.29154967e-03]])

# %%
f = np.array(save_predictions)[ix]
#f = np.array(save_predictions)
for i, y_pred in enumerate(f):
    #print(np.std(y_pred,axis=0))
    plot(y_pred, Y_test)

# %% [markdown]
# # BDNN Erythromycin rescistance Forecasting

# %%
decay=0.9
bs = 5
dp_prob = 0.15
BN=True
hidden= 500
samples = 3000
iterations=  5 * 1000
model_lam = 1e-1

# %%
num_periods, f_horizon = 7, 1
features = Erythromycin_X.shape[1]

# %%
x_batches, y_batches = train_data(Erythromycin_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Erythromycin_X, num_periods,f_horizon)

# %%
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)

# %% [markdown]
# # BDNN Pencillin rescistance Forecasting

# %%
decay=0.9
bs = 5
dp_prob = 0.95
BN=True
hidden= 500
samples = 3000
iterations=  5 * 1000
model_lam = 1e-6

# %%
num_periods, f_horizon = 7, 1
features = Pencillin_x.shape[1]

# %%
x_batches, y_batches = train_data(Pencillin_x, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = test_data(Pencillin_x, num_periods,f_horizon)

# %%
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,model_lam=model_lam
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                                        BN=BN,decay=decay,
                                                                                        dp_prob=dp_prob,hidden=hidden,
                                                                                       model_lam=model_lam
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test)
