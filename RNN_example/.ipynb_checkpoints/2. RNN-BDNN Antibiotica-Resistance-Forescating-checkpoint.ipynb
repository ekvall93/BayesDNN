# %%
import tensorflow as tf
import random
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from utils import plot, get_time_series
# %matplotlib inline

np.random.seed(14)
# Out:
# /home/ekvall/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = pd.read_csv("assets/rspb20170679_si_005.csv")

df.columns = ["Year","Pencillin(R)", "Erythromycin(R)","Multidrug(R)","Amoxicillin(C)",
              "Amoxicillin-Clavunate(C)","Amoxicillin-Total(C)","Cephalosporins(C)",
              "Azithromycin(C)","ConcTotal(C)"]
df = df.set_index("Year")
df.head(2)
# Out:
#              Pencillin(R)  Erythromycin(R)  Multidrug(R)  Amoxicillin(C)  \
# Year
# 1999.000000       19.9071          0.00000      0.050406         222.186
# 1999.083333       47.2212          2.51094      9.361640         251.312
#
#              Amoxicillin-Clavunate(C)  Amoxicillin-Total(C)  \
# Year
# 1999.000000                   67.4306              289.6166
# 1999.083333                   71.1567              322.4687
#
#              Cephalosporins(C)  Azithromycin(C)  ConcTotal(C)
# Year
# 1999.000000            37.6809          4.12793       358.506
# 1999.083333            25.5851          2.61499       382.361

# %%
Multidrug_X = df[["Multidrug(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values
Erythromycin_X = df[["Erythromycin(R)",
                 "Azithromycin(C)","Amoxicillin-Total(C)"]].values
Pencillin_x = df[["Pencillin(R)","Cephalosporins(C)",
                 "Azithromycin(C)"]].values

# %%
from tensorflow.contrib.distributions import Bernoulli

class StochasticRNNLayer:
    """
    StochasticLayer Dense Layer.

    Parameters
    ----------
    BN : bool
        Batchnormalization
    n_in : int
        Input nodes
    n_out: int
        Output nodes
    model_prob: float
        Dropout probability
    model_lam: float
        regualarization term
    is_training: bool
        traing-phase/test-phase        
    
    Returns
    -------
    array
        Outputlayer
    """
    

    def __init__(self, n_in, n_out, model_prob, is_training, BN=False, decay=0.99):
        tf.set_random_seed(14)
        
        
        self.n_in = n_in
        self.n_out = n_out
        
        self.is_training = is_training    
        self.model_prob = model_prob       
        self.BN = BN
        self.scale = tf.Variable(tf.ones([n_out]))
        self.beta = tf.Variable(tf.zeros([n_out]))
        self.epsilon = 1e-2
        self.mean = tf.Variable(tf.zeros([n_out]), trainable=False)
        self.var = tf.Variable(tf.ones([n_out]), trainable=False)
        self.decay = decay

    def __call__(self, X, activation=tf.identity):
        
        basic_cell = tf.contrib.rnn.OutputProjectionWrapper(
            tf.contrib.rnn.BasicRNNCell(num_units=self.n_in, activation=tf.nn.tanh),
            output_size=self.n_in
        )
                
        basic_cell = tf.contrib.rnn.DropoutWrapper(basic_cell, input_keep_prob=self.model_prob[0], output_keep_prob=self.model_prob[1], state_keep_prob=self.model_prob[2])
        rnn_output, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)
        output = tf.reshape(rnn_output, [-1, self.n_in])
        
        
        if self.BN:
            output = self.batch_norm_wrapper(output)
                
        return output

   
    
    def batch_norm_wrapper(self, inputs):
        """
        Batchnormalization

        Parameters
        ----------
        inputs : array
            Batch input
        is_training : bool
            training phase/test phase
        decay: float
            Decrease training of popoulation mean and variance.    
        Returns
        -------
        array
            Normalized batched
        """
        
        
        
        def BN_train():
            """
            Batchnormalization training
 
            Returns
            -------
            array
                Normalized train batch
            """
            batch_mean, batch_var = tf.nn.moments(inputs,[0])
            train_mean = tf.assign(self.mean, self.mean * self.decay + batch_mean * (1 - self.decay))
            train_var = tf.assign(self.var, self.var * self.decay + batch_var * (1 - self.decay))
            #train_mean = tf.assign(self.mean, self.mean + batch_mean)
            #train_var = tf.assign(self.var, self.var + batch_var)
            
            with tf.control_dependencies([train_mean, train_var]):
                return tf.nn.batch_normalization(inputs,
                    batch_mean, batch_var, self.beta, self.scale, self.epsilon)
            
        def BN_test():
            """
            Batchnormalization test
 
            Returns
            -------
            array
                Normalized test batched
            """
            return tf.nn.batch_normalization(inputs,
                self.mean, self.var, self.beta, self.scale, self.epsilon)
        
        
        return tf.cond(self.is_training, BN_train, BN_test)

# %%
def build_graph(num_periods, features, learning_rate=0.01, dp_prob=np.array([1.0,1.0,1.0]), BN=False, decay=0.99,hidden=100,bs=10):
    tf.set_random_seed(14)
    inputs = features
    hidden = hidden
    output = 1
    model_prob = dp_prob
    learning_rate = learning_rate



    X = tf.placeholder(tf.float32, [None, num_periods, inputs])
    y = tf.placeholder(tf.float32, [None, num_periods, output])

    is_training = tf.placeholder(tf.bool)
    
    Layer_1 = StochasticRNNLayer(hidden, hidden, model_prob, is_training ,BN=BN, decay=decay)

    z_1 = Layer_1(X, tf.nn.tanh)

    stacked_outputs = tf.layers.dense(z_1, output)
    y_pred = tf.reshape(stacked_outputs, [-1, num_periods, output])
    sse = tf.reduce_sum(tf.square(y_pred - y)) 
    mse = sse / bs
    
    model_loss = (
        # Negative log-likelihood.
        sse 
                ) / bs
    
    
    train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(model_loss)

    return (X, y), train_step, mse, y_pred, tf.train.Saver(), is_training

# %%
def train(x_batches,y_batch,iterations=2000, verbose =True, bs=10):
    """
    Train model

    Parameters
    ----------
    iterations : int
        Number of iterations
    verbose : bool
        Verbose
    bs: int
        batch-size
    """
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(iterations):
            #Run it in batches.
            test_idx = np.arange(0 , len(x_batches[1]))
            X_batch = x_batches[test_idx[:bs]]
            y_batch = y_batches[test_idx[:bs]]
            train_step.run(feed_dict={X_input: X_batch, y_input: y_batch, is_training:True})
            if verbose:
                if i % 100 == 0:
                    print(i)
                    mse = sess.run(model_mse, {X_input: X_batch, y_input: y_batch, is_training:True})
                    print("Iteration {}, Mean squared errror: {:.7f}".format(i, mse))
        saved_model = saver.save(sess, 'temp/temp-bn-save')
        sess.close()

# %%
def test(x_batches,X_test,features,samples=1000, bs=10,BN=False):
    """
    Test model

    Parameters
    ----------
    samples : int
        Monte Carlo Samples
    bs : int
        Batchnorm samples
    """
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        saver.restore(sess, 'temp/temp-bn-save')
    

        Y_sample = np.zeros((samples, x_batches.shape[1], features))
        for i in range(samples):       
            if BN:
                test_idx = np.arange(0 , x_batches.shape[0])
                np.random.shuffle(test_idx)
                model_pred.eval({X_input: x_batches[test_idx[:bs]],  is_training: True})
            Y_sample[i] = sess.run(model_pred, {X_input: X_test, is_training: False})
        return Y_sample

# %% [markdown]
# # BDNN Multidrug rescistance Forecasting

# %%
param = [8.4e-01, 7.7e-01, 6.0e-01, 5.5e-01,
        1.3e+02, 5.0e+00, 4.6e-04]

# %%
num_periods, f_horizon = 7, 1
decay=param[0]
bs = int(param[5])
dp_prob = np.array([param[1],param[2],param[3]])
BN=True
hidden= int(param[4])
samples = 3000
iterations=  5 * 1000
lr = param[6]

# %%
features = Multidrug_X.shape[1]
x_batches, y_batches = get_time_series(Multidrug_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)
# Out:
# 0
# Iteration 0, Mean squared errror: 2957.8103027
# 100
# Iteration 100, Mean squared errror: 2612.6257324
# 200
# Iteration 200, Mean squared errror: 2300.2734375
# 300
# Iteration 300, Mean squared errror: 2047.5369873
# 400
# Iteration 400, Mean squared errror: 1469.5772705
# 500
# Iteration 500, Mean squared errror: 929.0310669
# 600
# Iteration 600, Mean squared errror: 553.8204956
# 700
# Iteration 700, Mean squared errror: 548.9473877
# 800
# Iteration 800, Mean squared errror: 338.0493774
# 900
# Iteration 900, Mean squared errror: 480.3058777
# 1000
# Iteration 1000, Mean squared errror: 461.7355042
# 1100
# Iteration 1100, Mean squared errror: 366.0523987
# 1200
# Iteration 1200, Mean squared errror: 496.3700867
# 1300
# Iteration 1300, Mean squared errror: 439.2220154
# 1400
# Iteration 1400, Mean squared errror: 297.9779663
# 1500
# Iteration 1500, Mean squared errror: 501.3097839
# 1600
# Iteration 1600, Mean squared errror: 241.7974396
# 1700
# Iteration 1700, Mean squared errror: 230.7987366
# 1800
# Iteration 1800, Mean squared errror: 350.6181335
# 1900
# Iteration 1900, Mean squared errror: 480.3898621
# 2000
# Iteration 2000, Mean squared errror: 306.8197937
# 2100
# Iteration 2100, Mean squared errror: 194.1440582
# 2200
# Iteration 2200, Mean squared errror: 558.2636108
# 2300
# Iteration 2300, Mean squared errror: 303.9594421
# 2400
# Iteration 2400, Mean squared errror: 409.7153015
# 2500
# Iteration 2500, Mean squared errror: 354.2782288
# 2600
# Iteration 2600, Mean squared errror: 350.8269348
# 2700
# Iteration 2700, Mean squared errror: 229.4485931
# 2800
# Iteration 2800, Mean squared errror: 339.0890198
# 2900
# Iteration 2900, Mean squared errror: 228.5200195
# 3000
# Iteration 3000, Mean squared errror: 275.0173645
# 3100
# Iteration 3100, Mean squared errror: 510.8019714
# 3200
# Iteration 3200, Mean squared errror: 211.9417267
# 3300
# Iteration 3300, Mean squared errror: 354.0681458
# 3400
# Iteration 3400, Mean squared errror: 270.4845276
# 3500
# Iteration 3500, Mean squared errror: 237.7161865
# 3600
# Iteration 3600, Mean squared errror: 212.1792450
# 3700
# Iteration 3700, Mean squared errror: 230.3854523
# 3800
# Iteration 3800, Mean squared errror: 190.3603210
# 3900
# Iteration 3900, Mean squared errror: 183.7232819
# 4000
# Iteration 4000, Mean squared errror: 235.6314240
# 4100
# Iteration 4100, Mean squared errror: 445.0562439
# 4200
# Iteration 4200, Mean squared errror: 358.4487915
# 4300
# Iteration 4300, Mean squared errror: 419.7680359
# 4400
# Iteration 4400, Mean squared errror: 194.7094727
# 4500
# Iteration 4500, Mean squared errror: 125.6050034
# 4600
# Iteration 4600, Mean squared errror: 302.7598572
# 4700
# Iteration 4700, Mean squared errror: 272.9771118
# 4800
# Iteration 4800, Mean squared errror: 403.0013428
# 4900
# Iteration 4900, Mean squared errror: 483.5463867

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                                       
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test, "Multidrug resistance forecast","Multidrug")

# %% [markdown]
# # BDNN Erythromycin rescistance Forecasting

# %%
param = [5.2e-01, 9.2e-01, 5.9e-01, 7.4e-01,
        1.8e+02, 7.0e+00, 1.0e-03]

# %%
features = Multidrug_X.shape[1]
x_batches, y_batches = get_time_series(Erythromycin_X, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)
# Out:
# 0
# Iteration 0, Mean squared errror: 2517.1323242
# 100
# Iteration 100, Mean squared errror: 2093.4079590
# 200
# Iteration 200, Mean squared errror: 1792.9852295
# 300
# Iteration 300, Mean squared errror: 1699.7030029
# 400
# Iteration 400, Mean squared errror: 1223.0803223
# 500
# Iteration 500, Mean squared errror: 844.8629150
# 600
# Iteration 600, Mean squared errror: 590.7682495
# 700
# Iteration 700, Mean squared errror: 548.9491577
# 800
# Iteration 800, Mean squared errror: 577.3778687
# 900
# Iteration 900, Mean squared errror: 661.3765259
# 1000
# Iteration 1000, Mean squared errror: 603.5671997
# 1100
# Iteration 1100, Mean squared errror: 439.9635925
# 1200
# Iteration 1200, Mean squared errror: 489.6783142
# 1300
# Iteration 1300, Mean squared errror: 499.7920532
# 1400
# Iteration 1400, Mean squared errror: 321.0367126
# 1500
# Iteration 1500, Mean squared errror: 814.9486694
# 1600
# Iteration 1600, Mean squared errror: 292.4996033
# 1700
# Iteration 1700, Mean squared errror: 664.9796143
# 1800
# Iteration 1800, Mean squared errror: 652.8068848
# 1900
# Iteration 1900, Mean squared errror: 484.3993835
# 2000
# Iteration 2000, Mean squared errror: 285.7993469
# 2100
# Iteration 2100, Mean squared errror: 427.1540222
# 2200
# Iteration 2200, Mean squared errror: 293.8432007
# 2300
# Iteration 2300, Mean squared errror: 197.6516876
# 2400
# Iteration 2400, Mean squared errror: 520.1153564
# 2500
# Iteration 2500, Mean squared errror: 585.4180298
# 2600
# Iteration 2600, Mean squared errror: 593.0776978
# 2700
# Iteration 2700, Mean squared errror: 342.0439148
# 2800
# Iteration 2800, Mean squared errror: 323.6939697
# 2900
# Iteration 2900, Mean squared errror: 366.8453979
# 3000
# Iteration 3000, Mean squared errror: 269.5603943
# 3100
# Iteration 3100, Mean squared errror: 242.6848907
# 3200
# Iteration 3200, Mean squared errror: 172.4086914
# 3300
# Iteration 3300, Mean squared errror: 243.1072540
# 3400
# Iteration 3400, Mean squared errror: 463.7871704
# 3500
# Iteration 3500, Mean squared errror: 499.1775818
# 3600
# Iteration 3600, Mean squared errror: 202.0319366
# 3700
# Iteration 3700, Mean squared errror: 152.8978271
# 3800
# Iteration 3800, Mean squared errror: 265.3152161
# 3900
# Iteration 3900, Mean squared errror: 302.4064941
# 4000
# Iteration 4000, Mean squared errror: 244.3970184
# 4100
# Iteration 4100, Mean squared errror: 469.4859314
# 4200
# Iteration 4200, Mean squared errror: 401.4050293
# 4300
# Iteration 4300, Mean squared errror: 442.4275513
# 4400
# Iteration 4400, Mean squared errror: 445.4318848
# 4500
# Iteration 4500, Mean squared errror: 302.4344788
# 4600
# Iteration 4600, Mean squared errror: 343.4971008
# 4700
# Iteration 4700, Mean squared errror: 207.0095673
# 4800
# Iteration 4800, Mean squared errror: 464.8815002
# 4900
# Iteration 4900, Mean squared errror: 323.6683044

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                                       
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test,"Erythromycin resistance forecast","Erythromycin")

# %% [markdown]
# # BDNN Pencillin rescistance Forecasting

# %%
param = [7.8e-01, 8.4e-01, 5.5e-01, 9.9e-01,
        1.6e+02, 7.0e+00, 6.0e-04]

# %%
num_periods, f_horizon = 7, 1
decay=param[0]
bs = int(param[5])
dp_prob = np.array([param[1],param[2],param[3]])
BN=True
hidden= int(param[4])
samples = 3000
iterations=  5 * 1000
lr = param[6]

# %%
features = Multidrug_X.shape[1]
x_batches, y_batches = get_time_series(Pencillin_x, num_periods=num_periods, f_horizon=f_horizon)
X_test, Y_test = np.expand_dims(x_batches[-1,:,:],0), np.expand_dims(y_batches[-1,:,:],0)
x_batches, y_batches = x_batches[:-1,:,:], y_batches[:-1,:,:]
y_batches = np.expand_dims(y_batches[:,:,0],2)
Y_test = np.expand_dims(Y_test[:,:,0],2)

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, _, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                              )
train(x_batches, y_batches, iterations=iterations,verbose = True, bs=bs)
# Out:
# 0
# Iteration 0, Mean squared errror: 4150.9526367
# 100
# Iteration 100, Mean squared errror: 3686.5573730
# 200
# Iteration 200, Mean squared errror: 2916.2316895
# 300
# Iteration 300, Mean squared errror: 1560.2310791
# 400
# Iteration 400, Mean squared errror: 810.9832153
# 500
# Iteration 500, Mean squared errror: 469.7763977
# 600
# Iteration 600, Mean squared errror: 318.4103088
# 700
# Iteration 700, Mean squared errror: 365.9917603
# 800
# Iteration 800, Mean squared errror: 449.2907104
# 900
# Iteration 900, Mean squared errror: 296.3053589
# 1000
# Iteration 1000, Mean squared errror: 293.8353882
# 1100
# Iteration 1100, Mean squared errror: 234.0808258
# 1200
# Iteration 1200, Mean squared errror: 295.8973694
# 1300
# Iteration 1300, Mean squared errror: 194.7400665
# 1400
# Iteration 1400, Mean squared errror: 211.0369415
# 1500
# Iteration 1500, Mean squared errror: 361.7391052
# 1600
# Iteration 1600, Mean squared errror: 160.2998505
# 1700
# Iteration 1700, Mean squared errror: 261.2491455
# 1800
# Iteration 1800, Mean squared errror: 193.5890350
# 1900
# Iteration 1900, Mean squared errror: 189.1814728
# 2000
# Iteration 2000, Mean squared errror: 203.4887848
# 2100
# Iteration 2100, Mean squared errror: 170.4696960
# 2200
# Iteration 2200, Mean squared errror: 193.8211365
# 2300
# Iteration 2300, Mean squared errror: 143.3668823
# 2400
# Iteration 2400, Mean squared errror: 222.1664429
# 2500
# Iteration 2500, Mean squared errror: 183.8065643
# 2600
# Iteration 2600, Mean squared errror: 218.4710846
# 2700
# Iteration 2700, Mean squared errror: 166.0373535
# 2800
# Iteration 2800, Mean squared errror: 153.9160004
# 2900
# Iteration 2900, Mean squared errror: 183.7293854
# 3000
# Iteration 3000, Mean squared errror: 177.7609406
# 3100
# Iteration 3100, Mean squared errror: 160.9085236
# 3200
# Iteration 3200, Mean squared errror: 159.1018372
# 3300
# Iteration 3300, Mean squared errror: 83.4636993
# 3400
# Iteration 3400, Mean squared errror: 185.1351013
# 3500
# Iteration 3500, Mean squared errror: 157.7311249
# 3600
# Iteration 3600, Mean squared errror: 104.9795303
# 3700
# Iteration 3700, Mean squared errror: 153.0453949
# 3800
# Iteration 3800, Mean squared errror: 107.9400101
# 3900
# Iteration 3900, Mean squared errror: 105.9640427
# 4000
# Iteration 4000, Mean squared errror: 100.8414612
# 4100
# Iteration 4100, Mean squared errror: 122.1530991
# 4200
# Iteration 4200, Mean squared errror: 143.9643402
# 4300
# Iteration 4300, Mean squared errror: 104.9469528
# 4400
# Iteration 4400, Mean squared errror: 165.7178497
# 4500
# Iteration 4500, Mean squared errror: 123.4176788
# 4600
# Iteration 4600, Mean squared errror: 150.1713409
# 4700
# Iteration 4700, Mean squared errror: 80.9562912
# 4800
# Iteration 4800, Mean squared errror: 72.1134872
# 4900
# Iteration 4900, Mean squared errror: 102.4820251

# %%
tf.reset_default_graph()
(X_input, y_input), train_step, model_mse, model_pred, saver, is_training = build_graph(num_periods,features,
                                                                BN=BN,decay=decay,dp_prob=dp_prob,hidden=hidden,
                                                                bs=bs,learning_rate=lr
                                                                                       
                                                                                       )
Y_sample_DP = test(x_batches,X_test,features,samples, bs=bs,BN=BN)
# Out:
# INFO:tensorflow:Restoring parameters from temp/temp-bn-save

# %%
Y_sample_DP = np.expand_dims(Y_sample_DP[:,:,0],-1)
Y_test = np.expand_dims(Y_test[:,:,0],-1)

# %%
plot(Y_sample_DP, Y_test,"Pencillin resistance forecast","Pencillin")
